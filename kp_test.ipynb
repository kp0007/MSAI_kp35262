# %% [markdown]
# <a href="https://colab.research.google.com/github/kp0007/MSAI_kp35262/blob/main/kp_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mplcursors

# %%
# prompt: check python package matplotlib version

import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
# Import necessary packages
from google.colab import files
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import mplcursors

# %%
# Load patients data
d1 = files.upload()
patients = pd.read_csv('PATIENTS.csv')
# Out:
#      <input type="file" id="files-39dbec7e-7044-47c5-aab4-bb2d7cc60553" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39dbec7e-7044-47c5-aab4-bb2d7cc60553">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load patients data
d2 = files.upload()
admissions = pd.read_csv('ADMISSIONS.csv')
# Out:
#      <input type="file" id="files-e43961e2-7af2-44b9-9315-a0775201e500" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e43961e2-7af2-44b9-9315-a0775201e500">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
d2_unique = admissions.drop_duplicates(subset=['subject_id'])
d2_unique['subject_id'].value_counts()
# Out:
# subject_id
# 10006    1
# 40687    1
# 42231    1
# 42199    1
# 42135    1
#         ..
# 10089    1
# 10088    1
# 10083    1
# 10076    1
# 44228    1
# Name: count, Length: 100, dtype: int64

# %%
m1_pat_adm_uni = pd.merge(patients, d2_unique, on='subject_id')
m1_pat_adm_uni.head()
# Out:
#    row_id_x  subject_id gender                  dob                  dod  \
# 0      9467       10006      F  2094-03-05 00:00:00  2165-08-12 00:00:00
# 1      9472       10011      F  2090-06-05 00:00:00  2126-08-28 00:00:00
# 2      9474       10013      F  2038-09-03 00:00:00  2125-10-07 00:00:00
# 3      9478       10017      F  2075-09-21 00:00:00  2152-09-12 00:00:00
# 4      9479       10019      M  2114-06-20 00:00:00  2163-05-15 00:00:00
#
#               dod_hosp              dod_ssn  expire_flag  row_id_y  hadm_id  \
# 0  2165-08-12 00:00:00  2165-08-12 00:00:00            1     12258   142345
# 1  2126-08-28 00:00:00                  NaN            1     12263   105331
# 2  2125-10-07 00:00:00  2125-10-07 00:00:00            1     12265   165520
# 3                  NaN  2152-09-12 00:00:00            1     12269   199207
# 4  2163-05-15 00:00:00  2163-05-15 00:00:00            1     12270   177759
#
# ...

# %%
m1_pat_adm_uni['subject_id'].value_counts()
# Out:
# subject_id
# 10006    1
# 40687    1
# 42231    1
# 42199    1
# 42135    1
#         ..
# 10089    1
# 10088    1
# 10083    1
# 10076    1
# 44228    1
# Name: count, Length: 100, dtype: int64

# %%
m1_pat_adm_uni['insurance'].value_counts()
# Out:
# insurance
# Medicare      76
# Private       19
# Medicaid       4
# Government     1
# Name: count, dtype: int64

# %%
labels = ['Medicare', 'Private', 'Medicaid', 'Government']
sizes = [76, 19, 4, 1]
fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
for text in texts:
    text.set_color('black')
for autotext in autotexts:
autotext.set_color('white')
plt.title('Insurance Distribution')
cursor = mplcursors.cursor(wedges, hover=True)
@cursor.connect("add")
def on_add(sel):
    sel.annotation.set_text(f'{labels[sel.index]}: {sizes[sel.index]}')
plt.show()
# Out:
#   File "<ipython-input-44-3359407d3a6b>", line 8
#     autotext.set_color('white')
#     ^
# IndentationError: expected an indented block after 'for' statement on line 7

# %%
labels = ['Medicare', 'Private', 'Medicaid', 'Government']
sizes = [76, 19, 4, 1]
fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
for text in texts:
    text.set_color('black')
for autotext in autotexts:
    autotext.set_color('white') #This line was not indented properly and has been fixed.
plt.title('Insurance Distribution')
cursor = mplcursors.cursor(wedges, hover=True)
@cursor.connect("add")
def on_add(sel):
    sel.annotation.set_text(f'{labels[sel.index]}: {sizes[sel.index]}')
plt.show()
